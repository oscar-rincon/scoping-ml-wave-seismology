# %%
import networkx as nx
import nx2vos

# Read VOSviewer files
G = nx2vos.read_vos_files("map.txt", "network.txt")

# You can now analyze the network using networkx
print(nx.info(G))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 5
#       2 import nx2vos
#       4 # Read VOSviewer files
# ----> 5 G = nx2vos.read_vos_files("map.txt", "network.txt")
#       7 # You can now analyze the network using networkx
#       8 print(nx.info(G))
#
# AttributeError: module 'nx2vos' has no attribute 'read_vos_files'
